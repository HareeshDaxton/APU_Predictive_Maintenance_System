# %%
import pandas as pd
import yaml
import numpy as np

# %%
train_path = r'E:\APU_Predictive_Maintenance\Artifacts\preprocessed\train_preprocessed\train_preprocessed.csv'
test_path = r'E:\APU_Predictive_Maintenance\Artifacts\preprocessed\test_preprocessed\\test_preprocessed.csv'
# Out:
# E:\APU_Predictive_Maintenance\Artifacts\preprocessed\train_preprocessed\train_preprocessed.csv

# %%
    
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
drop_columns = [
                'engine_id',
                'cycle',
                "fault_label",
                "fault_type",
                "fault_target",
                "RUL",
 ]
            
x = train_df.drop(columns=drop_columns, errors='ignore')
y = test_df['RUL']

# %%
x.head()
# Out:
#    op_setting_1  op_setting_2  op_setting_3  sensor_1  sensor_2  sensor_3  \
# 0      0.746493      0.864455      0.417725 -0.889706 -0.291006 -0.187969
# 1      0.746493      0.864455      0.417725 -0.889706 -0.291006 -0.187969
# 2      0.746493      0.864455      0.417725 -0.889706 -0.291006 -0.187969
# 3      0.746493      0.864455      0.417725 -0.889706 -0.291006  2.064381
# 4      0.746493      0.864455      0.417725 -0.889706 -0.291006 -0.187969
#
#    sensor_4  sensor_5  sensor_6  sensor_7  ...  sensor_15_trend  \
# 0  0.537852 -0.706737 -0.663514 -0.142581  ...        -0.004952
# 1  0.537852 -0.706737 -0.663514 -0.142581  ...        -0.004952
# 2  0.537852 -0.706737 -0.663514 -0.142581  ...        -0.004952
# 3  0.537852 -0.706737 -0.663514 -0.142581  ...        -0.004952
# 4  0.537852 -0.706737 -0.663514 -0.142581  ...        -0.004952
#
#    sensor_17_rolling_mean  sensor_17_rolling_std  sensor_17_trend  \
# 0               -0.053141              -0.840616        -0.004565
# 1               -0.053141              -0.840616        -0.004565
# 2               -0.053141              -0.840616        -0.004565
# 3               -0.053141              -0.840616        -0.004565
# 4               -0.053141              -0.840616        -0.004565
#
#    sensor_20_rolling_mean  sensor_20_rolling_std  sensor_20_trend  \
# 0               -0.908486              -0.832405         0.002646
# 1               -0.908486              -0.832405         0.002646
# 2               -0.908486              -0.832405         0.002646
# 3               -0.908486              -0.832405         0.002646
# 4               -0.908486              -0.832405         0.002646
#
#    sensor_21_rolling_mean  sensor_21_rolling_std  sensor_21_trend
# 0               -1.561555              -0.830872         0.002677
# 1               -1.561555              -0.830872         0.002677
# 2               -1.561555              -0.830872         0.002677
# 3               -1.561555              -0.830872         0.002677
# 4               -1.561555              -0.830872         0.002677
#
# [5 rows x 68 columns]

# %%
y
# Out:
# 0        268
# 1        268
# 2        268
# 3        268
# 4        268
#         ...
# 65215      0
# 65216      0
# 65217      0
# 65218      0
# 65219      0
# Name: RUL, Length: 65220, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, y_train,
