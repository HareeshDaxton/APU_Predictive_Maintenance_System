# %%
import pandas as pd

# %%
df = pd.read_csv('Fault_injection_dataset.csv')
df.head(53761)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('Fault_injection_dataset.csv')
#       2 df.head(53761)
#
# File e:\APU_Predictive_Maintenance\.APU_venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df['fault_label'].value_counts()
# Out:
# fault_label
# 0    53759
# 1    53759
# 2    53759
# 3    53759
# 4    53759
# 5    53759
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.boxplot(data=df, x='fault_type', y='anomaly_score')
# Out:
# <Axes: xlabel='fault_type', ylabel='anomaly_score'>

# %%
import pandas as pd

df = pd.read_csv(r"e:\APU_Predictive_Maintenance\Artifacts\Fault_injected_data\Fault_injection_dataset.csv")
print( df.shape)
df.head(200)
# Out:
# (322554, 30)
#      engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0            1      1       34.9983        0.8400         100.0    449.44
# 1            1      2       41.9982        0.8408         100.0    445.00
# 2            1      3       24.9988        0.6218          60.0    462.54
# 3            1      4       42.0077        0.8416         100.0    445.00
# 4            1      5       25.0005        0.6203          60.0    462.54
# ..         ...    ...           ...           ...           ...       ...
# 195          2     47       35.0045        0.8400         100.0    449.44
# 196          2     48       25.0029        0.6208          60.0    462.54
# 197          2     49        0.0029        0.0005         100.0    518.67
# 198          2     50        0.0000        0.0019         100.0    518.67
# 199          2     51        0.0003        0.0002         100.0    518.67
#
# ...

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: e:\APU_Predictive_Maintenance\NoteBook\Expriments

# %%
df.isnull().sum()
# Out:
# engine_id        0
# cycle            0
# op_setting_1     0
# op_setting_2     0
# op_setting_3     0
# sensor_1         0
# sensor_2         0
# sensor_3         0
# sensor_4         0
# sensor_5         0
# sensor_6         0
# sensor_7         0
# sensor_8         0
# sensor_9         0
# sensor_10        0
# sensor_11        0
# sensor_12        0
# sensor_13        0
# sensor_14        0
# sensor_15        0
# sensor_16        0
# sensor_17        0
# sensor_18        0
# sensor_19        0
# sensor_20        0
# sensor_21        0
# anomaly_score    0
# fault_label      0
# fault_type       0
# fault_target     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322554 entries, 0 to 322553
# Data columns (total 30 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   engine_id      322554 non-null  int64
#  1   cycle          322554 non-null  int64
#  2   op_setting_1   322554 non-null  float64
#  3   op_setting_2   322554 non-null  float64
#  4   op_setting_3   322554 non-null  float64
#  5   sensor_1       322554 non-null  float64
#  6   sensor_2       322554 non-null  float64
#  7   sensor_3       322554 non-null  float64
#  8   sensor_4       322554 non-null  float64
#  9   sensor_5       322554 non-null  float64
#  10  sensor_6       322554 non-null  float64
#  11  sensor_7       322554 non-null  float64
#  12  sensor_8       322554 non-null  float64
#  13  sensor_9       322554 non-null  float64
#  14  sensor_10      322554 non-null  float64
#  15  sensor_11      322554 non-null  float64
# ...
